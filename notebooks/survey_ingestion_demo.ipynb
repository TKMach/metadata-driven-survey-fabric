# %% [markdown]
# # Fabric ingestion orchestration demo\nSanitized example; production identifiers and secrets are excluded.

# %% [markdown]
# 1. Load active metadata.\n2. Discover surveys.\n3. Detect changes.\n4. Build incremental windows.\n5. Exclude seen responses.\n6. Fetch and normalize details.\n7. MERGE Delta tables.\n8. Update successful checkpoints and run log.
